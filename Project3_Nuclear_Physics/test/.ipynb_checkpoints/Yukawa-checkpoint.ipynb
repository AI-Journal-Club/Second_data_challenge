# %%
import numpy as np
import torch
import torch.nn as nn

import sys
sys.path.insert(0, '../src')

from plot import plot_wavefunction, plot_wavefunctions
from sampling import TrainConfig
from scipy_eigensolver import solve_1channel
from training import train_Rayleigh, train_Rayleigh_PDE
from validation import validate

# %% [markdown]
# Define parameters

# %%
g = 8.22
a = 1.5 
mu = 1.0/a

r_min = 1e-4
r_max = 30.0
r = np.linspace(r_min, r_max, 1000)

# %% [markdown]
# Solve with scipy

# %%
def V(r):
    return - g**2 * np.exp(-mu * r) /  np.maximum(r, 1e-2)

E_scipy, u_scipy, R_scipy = solve_1channel(V, r)
plot_wavefunction(r, u_scipy, R_scipy, E_scipy)
# Out:
# Ground state energy E = -2.222665 MeV
# /Users/phongdang/Desktop/AI-JC/Second_data_challenge/Project3_Nuclear_Physics/test/../src/scipy_eigensolver.py:48: RuntimeWarning: overflow encountered in scalar multiply
#   if u_vals[i] * u_vals[i+1] < 0:

# %% [markdown]
# Define a neural network $N_\theta(r)$ that approximates the radial wave function via an ansatz
# $$
# u_\theta(r) = r e^{-\alpha r} N_{\theta}(r) \text{ with } \alpha = 0.25 \text{ fm}^{-1}.
# $$
# The network input is rescaled from $[0,r_{\max}]$ to $[-1,1]$.

# %%
class RadialNet(nn.Module):
    def __init__(self, hidden_dim=64, num_layers=3, alpha=0.25, energy_init=-3.0):
        # Define layers
        super().__init__()
        layers = [nn.Linear(1, hidden_dim), nn.Tanh()]
        for _ in range(num_layers - 1):
            layers += [nn.Linear(hidden_dim, hidden_dim), nn.Tanh()]
        layers.append(nn.Linear(hidden_dim, 1))
        self.net = nn.Sequential(*layers)

        self.register_buffer('alpha', torch.tensor(float(alpha)))
        self.energy = nn.Parameter(torch.tensor([energy_init], dtype=torch.float32))

        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.dtype = torch.float32

        self.r_min = r_min
        self.r_max = r_max

    # Forward pass
    def forward(self, r):
        # r is expected to be of shape (N, 1)
        x = 2.0 * r / self.r_max - 1.0 # mapping to [-1,1]
        return r * torch.exp(-self.alpha * r) * self.net(x)

    # Potential
    def potential(self, r):
        return -g**2 * torch.exp(-mu * r) / r

# %%
cfg = TrainConfig()
model = RadialNet()

history = train_Rayleigh(model, cfg)
# Out:
# {'step': 1, 'loss': 9.951008796691895, 'rayleigh': 0.9477424621582031, 'norm_loss': 0.9003183245658875, 'boundary_loss': 8.302373316837475e-06, 'E': 0.9477424621582031}
# {'step': 500, 'loss': -0.25374695658683777, 'rayleigh': -0.27490827441215515, 'norm_loss': 0.002115726238116622, 'boundary_loss': 4.043104127049446e-07, 'E': -0.27490827441215515}
# {'step': 1000, 'loss': -1.8125123977661133, 'rayleigh': -1.8187943696975708, 'norm_loss': 0.000628188718110323, 'boundary_loss': 9.703627235069234e-09, 'E': -1.8187943696975708}
# {'step': 1500, 'loss': -0.9857736229896545, 'rayleigh': -0.9877106547355652, 'norm_loss': 0.00019259854161646217, 'boundary_loss': 1.1001703796864604e-06, 'E': -0.9877106547355652}
# {'step': 2000, 'loss': -1.854386568069458, 'rayleigh': -1.854418158531189, 'norm_loss': 2.6621758024703013e-06, 'boundary_loss': 5.045228590461193e-07, 'E': -1.854418158531189}
# {'step': 2500, 'loss': -2.2770962715148926, 'rayleigh': -2.2772531509399414, 'norm_loss': 1.477651130699087e-05, 'boundary_loss': 9.115213401855726e-07, 'E': -2.2772531509399414}
# {'step': 3000, 'loss': -2.886849880218506, 'rayleigh': -2.8880455493927, 'norm_loss': 0.0001187558809760958, 'boundary_loss': 8.175692300937953e-07, 'E': -2.8880455493927}
# {'step': 3500, 'loss': -3.4091873168945312, 'rayleigh': -3.410003185272217, 'norm_loss': 7.976987399160862e-05, 'boundary_loss': 1.815496261770022e-06, 'E': -3.410003185272217}
# {'step': 4000, 'loss': -2.5337750911712646, 'rayleigh': -2.550151824951172, 'norm_loss': 0.0016373099060729146, 'boundary_loss': 3.6801677083531104e-07, 'E': -2.550151824951172}
# {'step': 4500, 'loss': -4.118319034576416, 'rayleigh': -4.127293586730957, 'norm_loss': 0.0008970145718194544, 'boundary_loss': 4.123424162116862e-07, 'E': -4.127293586730957}
# {'step': 5000, 'loss': -2.202138662338257, 'rayleigh': -2.2036454677581787, 'norm_loss': 0.00014860152441542596, 'boundary_loss': 2.083127810692531e-06, 'E': -2.2036454677581787}
# {'step': 5500, 'loss': -2.968461513519287, 'rayleigh': -3.031134605407715, 'norm_loss': 0.0062660942785441875, 'boundary_loss': 1.2056781315550325e-06, 'E': -3.031134605407715}
# {'step': 6000, 'loss': -0.4820934236049652, 'rayleigh': -0.4845302700996399, 'norm_loss': 0.00024219247279688716, 'boundary_loss': 1.4945335351512767e-06, 'E': -0.4845302700996399}
# {'step': 6500, 'loss': -0.7934876680374146, 'rayleigh': -0.7982374429702759, 'norm_loss': 0.000472729530883953, 'boundary_loss': 2.2499325496028177e-06, 'E': -0.7982374429702759}
# {'step': 7000, 'loss': -1.7383545637130737, 'rayleigh': -1.7824018001556396, 'norm_loss': 0.004403332713991404, 'boundary_loss': 1.395490357936069e-06, 'E': -1.7824018001556396}
# {'step': 7500, 'loss': -2.178431987762451, 'rayleigh': -2.192739486694336, 'norm_loss': 0.0014302608324214816, 'boundary_loss': 5.116717716191488e-07, 'E': -2.192739486694336}
# {'step': 8000, 'loss': -4.6088643074035645, 'rayleigh': -4.614357948303223, 'norm_loss': 0.000548322219401598, 'boundary_loss': 1.03051127098297e-06, 'E': -4.614357948303223}
# {'step': 8500, 'loss': -1.461800217628479, 'rayleigh': -1.4874858856201172, 'norm_loss': 0.0025684786960482597, 'boundary_loss': 8.81307826716693e-08, 'E': -1.4874858856201172}
# {'step': 9000, 'loss': -3.549621820449829, 'rayleigh': -3.6012957096099854, 'norm_loss': 0.005166132003068924, 'boundary_loss': 1.2632852985916543e-06, 'E': -3.6012957096099854}
# {'step': 9500, 'loss': -2.896338701248169, 'rayleigh': -2.943758010864258, 'norm_loss': 0.004740771371871233, 'boundary_loss': 1.1711078968801303e-06, 'E': -2.943758010864258}
# {'step': 10000, 'loss': -3.5283002853393555, 'rayleigh': -3.5503664016723633, 'norm_loss': 0.002203271258622408, 'boundary_loss': 3.32893159793457e-06, 'E': -3.5503664016723633}
# [{'step': 1,
#   'loss': 9.951008796691895,
#   'rayleigh': 0.9477424621582031,
#   'norm_loss': 0.9003183245658875,
#   'boundary_loss': 8.302373316837475e-06,
#   'E': 0.9477424621582031},
#  {'step': 500,
#   'loss': -0.25374695658683777,
#   'rayleigh': -0.27490827441215515,
#   'norm_loss': 0.002115726238116622,
#   'boundary_loss': 4.043104127049446e-07,
#   'E': -0.27490827441215515},
#  {'step': 1000,
#   'loss': -1.8125123977661133,
#   'rayleigh': -1.8187943696975708,
#   'norm_loss': 0.000628188718110323,
#   'boundary_loss': 9.703627235069234e-09,
#   'E': -1.8187943696975708},
#  {'step': 1500,
#   'loss': -0.9857736229896545,
#   'rayleigh': -0.9877106547355652,
#   'norm_loss': 0.00019259854161646217,
#   'boundary_loss': 1.1001703796864604e-06,
#   'E': -0.9877106547355652},
#  {'step': 2000,
#   'loss': -1.854386568069458,
#   'rayleigh': -1.854418158531189,
#   'norm_loss': 2.6621758024703013e-06,
#   'boundary_loss': 5.045228590461193e-07,
#   'E': -1.854418158531189},
#  {'step': 2500,
#   'loss': -2.2770962715148926,
#   'rayleigh': -2.2772531509399414,
#   'norm_loss': 1.477651130699087e-05,
#   'boundary_loss': 9.115213401855726e-07,
#   'E': -2.2772531509399414},
#  {'step': 3000,
#   'loss': -2.886849880218506,
#   'rayleigh': -2.8880455493927,
#   'norm_loss': 0.0001187558809760958,
#   'boundary_loss': 8.175692300937953e-07,
#   'E': -2.8880455493927},
#  {'step': 3500,
#   'loss': -3.4091873168945312,
#   'rayleigh': -3.410003185272217,
#   'norm_loss': 7.976987399160862e-05,
#   'boundary_loss': 1.815496261770022e-06,
#   'E': -3.410003185272217},
#  {'step': 4000,
#   'loss': -2.5337750911712646,
#   'rayleigh': -2.550151824951172,
#   'norm_loss': 0.0016373099060729146,
#   'boundary_loss': 3.6801677083531104e-07,
#   'E': -2.550151824951172},
#  {'step': 4500,
#   'loss': -4.118319034576416,
#   'rayleigh': -4.127293586730957,
#   'norm_loss': 0.0008970145718194544,
#   'boundary_loss': 4.123424162116862e-07,
#   'E': -4.127293586730957},
#  {'step': 5000,
#   'loss': -2.202138662338257,
#   'rayleigh': -2.2036454677581787,
#   'norm_loss': 0.00014860152441542596,
#   'boundary_loss': 2.083127810692531e-06,
#   'E': -2.2036454677581787},
#  {'step': 5500,
#   'loss': -2.968461513519287,
#   'rayleigh': -3.031134605407715,
#   'norm_loss': 0.0062660942785441875,
#   'boundary_loss': 1.2056781315550325e-06,
#   'E': -3.031134605407715},
#  {'step': 6000,
#   'loss': -0.4820934236049652,
#   'rayleigh': -0.4845302700996399,
#   'norm_loss': 0.00024219247279688716,
#   'boundary_loss': 1.4945335351512767e-06,
#   'E': -0.4845302700996399},
#  {'step': 6500,
#   'loss': -0.7934876680374146,
#   'rayleigh': -0.7982374429702759,
#   'norm_loss': 0.000472729530883953,
#   'boundary_loss': 2.2499325496028177e-06,
#   'E': -0.7982374429702759},
#  {'step': 7000,
#   'loss': -1.7383545637130737,
#   'rayleigh': -1.7824018001556396,
#   'norm_loss': 0.004403332713991404,
#   'boundary_loss': 1.395490357936069e-06,
#   'E': -1.7824018001556396},
#  {'step': 7500,
#   'loss': -2.178431987762451,
#   'rayleigh': -2.192739486694336,
#   'norm_loss': 0.0014302608324214816,
#   'boundary_loss': 5.116717716191488e-07,
#   'E': -2.192739486694336},
#  {'step': 8000,
#   'loss': -4.6088643074035645,
#   'rayleigh': -4.614357948303223,
#   'norm_loss': 0.000548322219401598,
#   'boundary_loss': 1.03051127098297e-06,
#   'E': -4.614357948303223},
#  {'step': 8500,
#   'loss': -1.461800217628479,
#   'rayleigh': -1.4874858856201172,
#   'norm_loss': 0.0025684786960482597,
#   'boundary_loss': 8.81307826716693e-08,
#   'E': -1.4874858856201172},
#  {'step': 9000,
#   'loss': -3.549621820449829,
#   'rayleigh': -3.6012957096099854,
#   'norm_loss': 0.005166132003068924,
#   'boundary_loss': 1.2632852985916543e-06,
#   'E': -3.6012957096099854},
#  {'step': 9500,
#   'loss': -2.896338701248169,
#   'rayleigh': -2.943758010864258,
#   'norm_loss': 0.004740771371871233,
#   'boundary_loss': 1.1711078968801303e-06,
#   'E': -2.943758010864258},
#  {'step': 10000,
#   'loss': -3.5283002853393555,
#   'rayleigh': -3.5503664016723633,
#   'norm_loss': 0.002203271258622408,
#   'boundary_loss': 3.32893159793457e-06,
#   'E': -3.5503664016723633}]

# %%
metrics, u_nn, R_nn = validate(r,
